# %% [markdown]
# # Model Building, Scoring & Evaluating (Logistic Regression)

# %%
# Imports
from snowflake.snowpark.session import Session
import snowflake.snowpark.functions as F

from snowflake.ml.modeling.linear_model import LogisticRegression
from snowflake.ml.modeling.metrics import *

import json
import pandas as pd
import seaborn as sns

# %%
# Create Snowpark Session
with open('creds.json') as f:
    connection_parameters = json.load(f)

session = Session.builder.configs(connection_parameters).create()
print(f"Current Database and schema: {session.get_fully_qualified_current_schema()}")
print(f"Current Warehouse: {session.get_current_warehouse()}")
# Out:
# Current Database and schema: "CC_DB"."PUBLIC"
# Current Warehouse: "CC_WH"

# %% [markdown]
# ### Model Building

# %%
application_record_balanced_sdf = session.table('CREDIT_RISK_PREPARED_BALANCED')
application_record_balanced_sdf.group_by('TARGET').count().show()
# Out:
# ----------------------
# |"TARGET"  |"COUNT"  |
# ----------------------
# |0         |29819    |
# |1         |29819    |
# ----------------------

# %%
# Using stratified sampling of the data. 
# Using sample_by allows us to sample based on one column and also specify the fractions of each value in the column.

train_sdf = application_record_balanced_sdf.sample_by("TARGET", {1: 0.8, 0: 0.8})
train_sdf = train_sdf.cache_result()
train_sdf.group_by('TARGET').count().show()
# Out:
# ----------------------
# |"TARGET"  |"COUNT"  |
# ----------------------
# |1         |23937    |
# |0         |23751    |
# ----------------------

# %%
# The test data set is the rest of the rows, by using minus we can exclude the rows from the train_sdf DataFrame

test_sdf = application_record_balanced_sdf.minus(train_sdf)
test_sdf.group_by('TARGET').count().show()
# Out:
# ----------------------
# |"TARGET"  |"COUNT"  |
# ----------------------
# |0         |6068     |
# |1         |4846     |
# ----------------------

# %%
# Save the training and test data into tables

train_sdf.write.save_as_table(table_name='CREDIT_RISK_PREPARED_BALANCED_TRAIN', mode='overwrite')
test_sdf.write.save_as_table(table_name='CREDIT_RISK_PREPARED_BALANCED_TEST', mode='overwrite')

train_sdf = session.table('CREDIT_RISK_PREPARED_BALANCED_TRAIN')
test_sdf = session.table('CREDIT_RISK_PREPARED_BALANCED_TEST')

# %%
# Fitting a LogisticRegression model using snowpark-ml
feature_cols = train_sdf.columns
feature_cols.remove('TARGET')
feature_cols.remove('ID')
target_col = 'TARGET'

lm = LogisticRegression(
    C=0.8, 
    solver='lbfgs',
    random_state=0, 
    input_cols=feature_cols, 
    label_cols=target_col, 
    output_cols=['PREDICTION']
    )
lm.fit(train_sdf)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[30], line 15
#       5 target_col = 'TARGET'
#       7 lm = LogisticRegression(
#       8     C=0.8,
#       9     solver='lbfgs',
#    (...)
#      13     output_cols=['PREDICTION']
#      14     )
# ---> 15 lm.fit(train_sdf)
#
# File ~/Desktop/PROJECTS/machine-learning-with-snowpark/.venv/lib/python3.9/site-packages/snowflake/ml/_internal/telemetry.py:552, in send_api_usage_telemetry.<locals>.decorator.<locals>.wrap(*args, **kwargs)
#     543 telemetry_args = dict(
#     544     func_name=_get_full_func_name(func),
#     545     function_category=TelemetryField.FUNC_CAT_USAGE.value,
#    (...)
#     549     custom_tags=custom_tags,
#     550 )
#     551 try:
# --> 552     return ctx.run(execute_func_with_statement_params)
#     553 except Exception as e:
#     554     if not isinstance(e, snowml_exceptions.SnowflakeMLException):
#     555         # already handled via a nested decorated function
#
# File ~/Desktop/PROJECTS/machine-learning-with-snowpark/.venv/lib/python3.9/site-packages/snowflake/ml/_internal/telemetry.py:513, in send_api_usage_telemetry.<locals>.decorator.<locals>.wrap.<locals>.execute_func_with_statement_params()
#     511 def execute_func_with_statement_params() -> _ReturnValue:
#     512     _patch_manager.set_statement_params(statement_params)
# --> 513     result = func(*args, **kwargs)
#     514     return update_stmt_params_if_snowpark_df(result, statement_params)
#
# File ~/Desktop/PROJECTS/machine-learning-with-snowpark/.venv/lib/python3.9/site-packages/snowflake/ml/modeling/framework/base.py:440, in BaseEstimator.fit(self, dataset)
#     438     data_sources = [data_source.DataFrameInfo(dataset.queries["queries"][-1])]
#     439 lineage_utils.set_data_sources(self, data_sources)
# --> 440 return self._fit(dataset)
#
# File ~/Desktop/PROJECTS/machine-learning-with-snowpark/.venv/lib/python3.9/site-packages/snowflake/ml/modeling/linear_model/logistic_regression.py:388, in LogisticRegression._fit(self, dataset)
#     375         dataset = pd_df
#     377 model_trainer = ModelTrainerBuilder.build(
#     378     estimator=self._sklearn_object,
#     379     dataset=dataset,
#    (...)
#     386     batch_size=self._batch_size,
#     387 )
# --> 388 self._sklearn_object = model_trainer.train()
#     389 self._is_fitted = True
#     390 self._generate_model_signatures(dataset)
#
# File ~/Desktop/PROJECTS/machine-learning-with-snowpark/.venv/lib/python3.9/site-packages/snowflake/ml/modeling/_internal/snowpark_implementations/snowpark_trainer.py:557, in SnowparkModelTrainer.train(self)
#     555     fit_wrapper_sproc = self._get_fit_wrapper_sproc(statement_params=statement_params, anonymous=True)
#     556 else:
# --> 557     fit_wrapper_sproc = self._get_fit_wrapper_sproc(statement_params=statement_params, anonymous=False)
#     559 try:
#     560     sproc_export_file_name: str = fit_wrapper_sproc(
#     561         self.session,
#     562         queries,
#    (...)
#     567         statement_params,
#     568     )
#
# File ~/Desktop/PROJECTS/machine-learning-with-snowpark/.venv/lib/python3.9/site-packages/snowflake/ml/modeling/_internal/snowpark_implementations/snowpark_trainer.py:226, in SnowparkModelTrainer._get_fit_wrapper_sproc(self, statement_params, anonymous)
#     222 model_spec = ModelSpecificationsBuilder.build(model=self.estimator)
#     224 fit_sproc_name = snowpark_utils.random_name_for_temp_object(snowpark_utils.TempObjectType.PROCEDURE)
# --> 226 relaxed_dependencies = pkg_version_utils.get_valid_pkg_versions_supported_in_snowflake_conda_channel(
#     227     pkg_versions=model_spec.pkgDependencies, session=self.session
#     228 )
#     229 packages = ["snowflake-snowpark-python", "snowflake-telemetry-python"] + relaxed_dependencies
#     231 fit_wrapper_sproc = self.session.sproc.register(
#     232     func=self._build_fit_wrapper_sproc(model_spec=model_spec),
#     233     is_permanent=False,
#    (...)
#     239     anonymous=anonymous,
#     240 )
#
# File ~/Desktop/PROJECTS/machine-learning-with-snowpark/.venv/lib/python3.9/site-packages/snowflake/ml/_internal/utils/pkg_version_utils.py:31, in get_valid_pkg_versions_supported_in_snowflake_conda_channel(pkg_versions, session, subproject)
#      29     return pkg_versions
#      30 else:
# ---> 31     return _get_valid_pkg_versions_supported_in_snowflake_conda_channel_async(pkg_versions, session, subproject)
#
# File ~/Desktop/PROJECTS/machine-learning-with-snowpark/.venv/lib/python3.9/site-packages/snowflake/ml/_internal/utils/pkg_version_utils.py:60, in _get_valid_pkg_versions_supported_in_snowflake_conda_channel_async(pkg_versions, session, subproject)
#      57     except IndexError:
#      58         cache[pkg_version] = None
# ---> 60 pkg_version_conda_list = _get_conda_packages_and_emit_warnings(pkg_versions)
#      62 return pkg_version_conda_list
#
# File ~/Desktop/PROJECTS/machine-learning-with-snowpark/.venv/lib/python3.9/site-packages/snowflake/ml/_internal/utils/pkg_version_utils.py:118, in _get_conda_packages_and_emit_warnings(pkg_versions)
#     116         pkg_version_warning_list.append([pkg_version, _RUNTIME_VERSION])
#     117     else:
# --> 118         raise RuntimeError(
#     119             f"Package {pkg_version} is not supported in snowflake conda channel for "
#     120             f"python runtime {_RUNTIME_VERSION}."
#     121         )
#     122 else:
#     123     tokens = pkg_version.split("==")
#
# RuntimeError: Package lightgbm==4.6.0 is not supported in snowflake conda channel for python runtime 3.9.

# %%
# The fitted model can be retrieved as a scikit-learn object

lm_local = lm.to_sklearn()
lm_local
# Out:
# LogisticRegression(C=0.8, random_state=0)

# %%
# Plotting Feature Coefficients

feature_coefficients = pd.DataFrame(lm_local.coef_.T,lm_local.feature_names_in_,columns=['Coefficient'])
feature_coefficients.sort_values('Coefficient').plot.barh(y='Coefficient', figsize=(5,15))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Plotting Feature Coefficients
# ----> 3 feature_coefficients = pd.DataFrame(lm_local.coef_.T,lm_local.feature_names_in_,columns=['Coefficient'])
#       4 feature_coefficients.sort_values('Coefficient').plot.barh(y='Coefficient', figsize=(5,15))
#
# AttributeError: 'LogisticRegression' object has no attribute 'coef_'
